# %%
# import psycopg2
import pandas as pd
import ipywidgets
import os
import sqlite3
import numpy as np
import plotly.graph_objects as go
from docx import Document
# !pip install python-docx
# from docx import Document
from datetime import datetime as dt

from ipywidgets import widgets, interactive_output, interact, interactive, fixed, widget

# %%
df = pd.read_excel("inventario.xlsx", sheet_name="Sheet1").ffill().set_index("Ciente")
# Out:
# C:\Users\USUARIO\anaconda3\envs\HR\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df.loc["Nlounge"]
# Out:
#                                  Producto  Cantidad  Valor Und    Valor
# Ciente
# Nlounge                        Lotus Root         5      37.96   189.80
# Nlounge              Juice - Happy Planet         6      29.25   175.50
# Nlounge            Pasta - Spaghetti, Dry         6      32.45   194.70
# Nlounge                    Sausage - Meat         6      16.53    99.18
# Nlounge            Pasta - Spaghetti, Dry         5      32.45   162.25
# Nlounge         Juice - Cranberry, 341 Ml         7      53.60   375.20
# Nlounge             Cheese - La Sauvagine         2      21.21    42.42
# Nlounge             Cheese - La Sauvagine         6      21.21   127.26
# Nlounge             Cheese - La Sauvagine         1      21.21    21.21
# Nlounge              Juice - Happy Planet         5      29.25   146.25
# Nlounge                    Sausage - Meat         6      16.53    99.18
# Nlounge             Cheese - La Sauvagine         7      21.21   148.47
# Nlounge         Juice - Cranberry, 341 Ml        16      53.60   857.60
# Nlounge            Pasta - Spaghetti, Dry        29      32.45   941.05
# Nlounge             Cheese - La Sauvagine         3      21.21    63.63
# Nlounge                        Lotus Root         4      37.96   151.84
# Nlounge                 Pheasants - Whole         5      40.35   201.75
# Nlounge            Pasta - Spaghetti, Dry        46      32.45  1492.70
# Nlounge                 Pheasants - Whole        16      40.35   645.60
# Nlounge  Paper Cocktail Umberlla 80 - 180        27      46.81  1263.87
# Nlounge                 Pheasants - Whole         3      40.35   121.05

# %%
NIT = "123456789-0"
invoice = Document()

invoice.add_heading("Factura", 0)

p_1 = invoice.add_paragraph()
p_1.add_run("NIT: ").bold = True
p_1.add_run(NIT)



# invoice.save("invoice.docx")
